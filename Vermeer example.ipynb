# %% [markdown]
# ## Some imports

# %%
from PIL import Image
import numpy as np

from ipywidgets import (interact)

import bokeh
from bokeh.plotting import (figure, show, output_notebook)
from bokeh.io import (push_notebook)

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2a0b74b2-6d22-4de6-96b9-c3844a98b70c">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Load the data
#
# ![The Astronomer -- by Vermeer](./vermeer.jpg)

# %%
img = Image.open('./vermeer.jpg').convert('L')
fdata = np.array(img.getdata()).astype('float32').reshape(img.size[::-1])
fdata = (fdata - fdata.min()) / (fdata.max() - fdata.min())
fdata.shape

# invert y-axis
data = fdata[::-1,:]

# %%
p = figure(x_range=(0, data.shape[1]), y_range=(0, data.shape[0]), plot_width=640, plot_height=700)
p.image(image=[data], x=0, y=0, dw=data.shape[1], dh=data.shape[0], palette=bokeh.palettes.viridis(255))
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5c50ee23-7212-43dc-822e-872cf27a9cc9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("5c50ee23-7212-43dc-822e-872cf27a9cc9");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5c50ee23-7212-43dc-822e-872cf27a9cc9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5c50ee23-7212-43dc-822e-872cf27a9cc9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"95413213-bdd0-4719-8c36-d35237a8f1b4":{"roots":{"references":[{"attributes":{"plot":{"id":"5a57b5e6-9b93-4578-bb95-ab9c0e0df642","subtype":"Figure","type":"Plot"}},"id":"96fc9fa4-efe4-41e8-bdbd-d0ded968bfc8","type":"ResetTool"},{"attributes":{"plot":{"id":"5a57b5e6-9b93-4578-bb95-ab9c0e0df642","subtype":"Figure","type":"Plot"}},"id":"6f43ae3c-693f-4cb2-975b-f368cb906cee","type":"HelpTool"},{"attributes":{"formatter":{"id":"54bc9980-ff8d-471f-a58b-82db57447f7d","type":"BasicTickFormatter"},"plot":{"id":"5a57b5e6-9b93-4578-bb95-ab9c0e0df642","subtype":"Figure","type":"Plot"},"ticker":{"id":"f71ad606-2b95-4fe2-8a6b-88507bd64829","type":"BasicTicker"}},"id":"a61531a6-0f69-4b68-bb16-b0f65e53abad","type":"LinearAxis"},{"attributes":{"data_source":{"id":"2a93a363-73b8-4fb6-ab77-088160fb5014","type":"ColumnDataSource"},"glyph":{"id":"0356102b-fdf5-47bc-8add-97bec8806b74","type":"Image"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"aca6d4a1-b868-4ea9-8926-0c9f9f2dd2ee","type":"Image"},"selection_glyph":null},"id":"f7885562-998e-4461-ac61-37a880d37481","type":"GlyphRenderer"},{"attributes":{"palette":["#440154","#440255","#440357","#450558","#45065A","#45085B","#46095C","#460B5E","#460C5F","#460E61","#470F62","#471163","#471265","#471466","#471567","#471669","#47186A","#48196B","#481A6C","#481C6E","#481D6F","#481E70","#482071","#482172","#482273","#482374","#472575","#472676","#472777","#472878","#472A79","#472B7A","#472C7B","#462D7C","#462F7C","#46307D","#46317E","#45327F","#45347F","#453580","#453681","#443781","#443982","#433A83","#433B83","#433C84","#423D84","#423E85","#424085","#414186","#414286","#404387","#404487","#3F4587","#3F4788","#3E4888","#3E4989","#3D4A89","#3D4B89","#3D4C89","#3C4D8A","#3C4E8A","#3B508A","#3B518A","#3A528B","#3A538B","#39548B","#39558B","#38568B","#38578C","#37588C","#37598C","#365A8C","#365B8C","#355C8C","#355D8C","#345E8D","#345F8D","#33608D","#33618D","#32628D","#32638D","#31648D","#31658D","#31668D","#30678D","#30688D","#2F698D","#2F6A8D","#2E6B8E","#2E6C8E","#2E6D8E","#2D6E8E","#2D6F8E","#2C708E","#2C718E","#2C728E","#2B738E","#2B748E","#2A758E","#2A768E","#2A778E","#29788E","#29798E","#287A8E","#287A8E","#287B8E","#277C8E","#277D8E","#277E8E","#267F8E","#26808E","#26818E","#25828E","#25838D","#24848D","#24858D","#24868D","#23878D","#23888D","#23898D","#22898D","#228A8D","#228B8D","#218C8D","#218D8C","#218E8C","#208F8C","#20908C","#20918C","#1F928C","#1F938B","#1F948B","#1F958B","#1F968B","#1E978A","#1E988A","#1E998A","#1E998A","#1E9A89","#1E9B89","#1E9C89","#1E9D88","#1E9E88","#1E9F88","#1EA087","#1FA187","#1FA286","#1FA386","#20A485","#20A585","#21A685","#21A784","#22A784","#23A883","#23A982","#24AA82","#25AB81","#26AC81","#27AD80","#28AE7F","#29AF7F","#2AB07E","#2BB17D","#2CB17D","#2EB27C","#2FB37B","#30B47A","#32B57A","#33B679","#35B778","#36B877","#38B976","#39B976","#3BBA75","#3DBB74","#3EBC73","#40BD72","#42BE71","#44BE70","#45BF6F","#47C06E","#49C16D","#4BC26C","#4DC26B","#4FC369","#51C468","#53C567","#55C666","#57C665","#59C764","#5BC862","#5EC961","#60C960","#62CA5F","#64CB5D","#67CC5C","#69CC5B","#6BCD59","#6DCE58","#70CE56","#72CF55","#74D054","#77D052","#79D151","#7CD24F","#7ED24E","#81D34C","#83D34B","#86D449","#88D547","#8BD546","#8DD644","#90D643","#92D741","#95D73F","#97D83E","#9AD83C","#9DD93A","#9FD938","#A2DA37","#A5DA35","#A7DB33","#AADB32","#ADDC30","#AFDC2E","#B2DD2C","#B5DD2B","#B7DD29","#BADE27","#BDDE26","#BFDF24","#C2DF22","#C5DF21","#C7E01F","#CAE01E","#CDE01D","#CFE11C","#D2E11B","#D4E11A","#D7E219","#DAE218","#DCE218","#DFE318","#E1E318","#E4E318","#E7E419","#E9E419","#ECE41A","#EEE51B","#F1E51C","#F3E51E","#F6E61F","#F8E621","#FDE724"]},"id":"02a617e5-d6ac-4f2f-998c-c782a62b9b7d","type":"LinearColorMapper"},{"attributes":{},"id":"f71ad606-2b95-4fe2-8a6b-88507bd64829","type":"BasicTicker"},{"attributes":{"plot":{"id":"5a57b5e6-9b93-4578-bb95-ab9c0e0df642","subtype":"Figure","type":"Plot"},"ticker":{"id":"f71ad606-2b95-4f ...

# %%
from hyper_canny import (smooth_sobel, edge_thinning, double_threshold, cp_edge_thinning, cp_double_threshold)

# %% [markdown]
# ### Sobel filter

# %%
sobel = smooth_sobel(data.copy(), 5, 2.0)

# %%
sobel_data = 1.0/sobel[:,:,2]

fig_sobel = figure(x_range=(0, data.shape[1]), y_range=(0, data.shape[0]), plot_width=640, plot_height=700)
img = fig_sobel.image(image=[sobel_data], x=0, y=0, dw=data.shape[1], dh=data.shape[0], palette='Viridis256')
show(fig_sobel)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="80a56e51-fb73-4537-bd8e-8000c5cda586"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("80a56e51-fb73-4537-bd8e-8000c5cda586");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("80a56e51-fb73-4537-bd8e-8000c5cda586");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '80a56e51-fb73-4537-bd8e-8000c5cda586' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"dc5b2315-0d97-4b39-9854-106a852a233d":{"roots":{"references":[{"attributes":{"data_source":{"id":"deda399a-e09f-46d9-bf3c-04baf4347067","type":"ColumnDataSource"},"glyph":{"id":"75813d6b-7f09-423f-b899-d2c48c4759f3","type":"Image"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9e1ca814-9f74-4aac-9f50-b9622eba41e0","type":"Image"},"selection_glyph":null},"id":"457e662b-4726-42ff-a4bc-7feb3a7171e2","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"7c5e93d5-b39d-4a7e-aadc-fc5cb57ea1a2","subtype":"Figure","type":"Plot"}},"id":"c4a83846-62ae-4923-b10b-ce2cdad71ce0","type":"WheelZoomTool"},{"attributes":{"palette":["#440154","#440255","#440357","#450558","#45065A","#45085B","#46095C","#460B5E","#460C5F","#460E61","#470F62","#471163","#471265","#471466","#471567","#471669","#47186A","#48196B","#481A6C","#481C6E","#481D6F","#481E70","#482071","#482172","#482273","#482374","#472575","#472676","#472777","#472878","#472A79","#472B7A","#472C7B","#462D7C","#462F7C","#46307D","#46317E","#45327F","#45347F","#453580","#453681","#443781","#443982","#433A83","#433B83","#433C84","#423D84","#423E85","#424085","#414186","#414286","#404387","#404487","#3F4587","#3F4788","#3E4888","#3E4989","#3D4A89","#3D4B89","#3D4C89","#3C4D8A","#3C4E8A","#3B508A","#3B518A","#3A528B","#3A538B","#39548B","#39558B","#38568B","#38578C","#37588C","#37598C","#365A8C","#365B8C","#355C8C","#355D8C","#345E8D","#345F8D","#33608D","#33618D","#32628D","#32638D","#31648D","#31658D","#31668D","#30678D","#30688D","#2F698D","#2F6A8D","#2E6B8E","#2E6C8E","#2E6D8E","#2D6E8E","#2D6F8E","#2C708E","#2C718E","#2C728E","#2B738E","#2B748E","#2A758E","#2A768E","#2A778E","#29788E","#29798E","#287A8E","#287A8E","#287B8E","#277C8E","#277D8E","#277E8E","#267F8E","#26808E","#26818E","#25828E","#25838D","#24848D","#24858D","#24868D","#23878D","#23888D","#23898D","#22898D","#228A8D","#228B8D","#218C8D","#218D8C","#218E8C","#208F8C","#20908C","#20918C","#1F928C","#1F938B","#1F948B","#1F958B","#1F968B","#1E978A","#1E988A","#1E998A","#1E998A","#1E9A89","#1E9B89","#1E9C89","#1E9D88","#1E9E88","#1E9F88","#1EA087","#1FA187","#1FA286","#1FA386","#20A485","#20A585","#21A685","#21A784","#22A784","#23A883","#23A982","#24AA82","#25AB81","#26AC81","#27AD80","#28AE7F","#29AF7F","#2AB07E","#2BB17D","#2CB17D","#2EB27C","#2FB37B","#30B47A","#32B57A","#33B679","#35B778","#36B877","#38B976","#39B976","#3BBA75","#3DBB74","#3EBC73","#40BD72","#42BE71","#44BE70","#45BF6F","#47C06E","#49C16D","#4BC26C","#4DC26B","#4FC369","#51C468","#53C567","#55C666","#57C665","#59C764","#5BC862","#5EC961","#60C960","#62CA5F","#64CB5D","#67CC5C","#69CC5B","#6BCD59","#6DCE58","#70CE56","#72CF55","#74D054","#77D052","#79D151","#7CD24F","#7ED24E","#81D34C","#83D34B","#86D449","#88D547","#8BD546","#8DD644","#90D643","#92D741","#95D73F","#97D83E","#9AD83C","#9DD93A","#9FD938","#A2DA37","#A5DA35","#A7DB33","#AADB32","#ADDC30","#AFDC2E","#B2DD2C","#B5DD2B","#B7DD29","#BADE27","#BDDE26","#BFDF24","#C2DF22","#C5DF21","#C7E01F","#CAE01E","#CDE01D","#CFE11C","#D2E11B","#D4E11A","#D7E219","#DAE218","#DCE218","#DFE318","#E1E318","#E4E318","#E7E419","#E9E419","#ECE41A","#EEE51B","#F1E51C","#F3E51E","#F6E61F","#F8E621","#FAE622","#FDE724"]},"id":"2e979d60-6ba8-4317-97c3-4fc7efb46242","type":"LinearColorMapper"},{"attributes":{"callback":null,"end":300},"id":"02141827-0c91-47c6-b6dd-724501e27274","type":"Range1d"},{"attributes":{"overlay":{"id":"52f40858-e9ee-4844-854d-ebeb64457d23","type":"BoxAnnotation"},"plot":{"id":"7c5e93d5-b39d-4a7e-aadc-fc5cb57ea1a2","subtype":"Figure","type":"Plot"}},"id":"2630c8c6-ff52-4d2f-82b9-a373618edde9","type":"BoxZoomTool"},{"attributes":{"palette":["#440154","#440255","#440357","#450558","#45065A","#45085B","#46095C","#460B5E","#460C5F","#460E61","#470F62","#471163","#471265","#471466","#471567","#471669","#47186A","#48196B","#481A6C","#481C6E","#481D6F","#481E70","#482071","#482172","#482273","#482374","#472575","#472676","#472777","#472878","#472A79","#472B7A" ...

# %% [markdown]
# ### Edge thinning

# %%
thin_edges = cp_edge_thinning(sobel)

# %%
fig_edges = figure(x_range=(0, data.shape[1]), y_range=(0, data.shape[0]), plot_width=640, plot_height=700)
img = fig_edges.image(image=[thin_edges], x=0, y=0, dw=data.shape[1], dh=data.shape[0], palette=bokeh.palettes.grey(2)[::-1])
show(fig_edges)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d1c68a97-0726-476d-84f3-e9651dbed974"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d1c68a97-0726-476d-84f3-e9651dbed974");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d1c68a97-0726-476d-84f3-e9651dbed974");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd1c68a97-0726-476d-84f3-e9651dbed974' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"21545fd7-aee3-4be0-9096-d9b309e80283":{"roots":{"references":[{"attributes":{"below":[{"id":"31b03019-8de7-4a31-9baa-588fa5acecb9","type":"LinearAxis"}],"left":[{"id":"76fc395e-dd43-4bb3-a236-0c9fc9a2294e","type":"LinearAxis"}],"plot_height":700,"plot_width":640,"renderers":[{"id":"31b03019-8de7-4a31-9baa-588fa5acecb9","type":"LinearAxis"},{"id":"0981332a-f48e-4cc2-a96a-57b5f9ac2c66","type":"Grid"},{"id":"76fc395e-dd43-4bb3-a236-0c9fc9a2294e","type":"LinearAxis"},{"id":"dfea6000-77d8-4bc8-bff0-c41c38b2b5ba","type":"Grid"},{"id":"4865db95-739f-480e-9d7e-62cb1d38614c","type":"BoxAnnotation"},{"id":"a499018b-02da-473c-9311-5cdf88ee020f","type":"GlyphRenderer"}],"title":{"id":"4dd23dee-564f-44db-8f29-73f29267aa29","type":"Title"},"tool_events":{"id":"1b013ec4-bbf9-4246-b4ed-905a55f4fe1c","type":"ToolEvents"},"toolbar":{"id":"15d172b5-79ea-40be-8982-eaf2f01629f2","type":"Toolbar"},"x_range":{"id":"7eee0909-85d6-4d75-b278-93a737c80d7f","type":"Range1d"},"x_scale":{"id":"e9fc8f12-2a66-4d48-8dae-eccf804db5ad","type":"LinearScale"},"y_range":{"id":"bdae3ee3-e1bf-4fb7-bf0f-8ad347485f77","type":"Range1d"},"y_scale":{"id":"455c7866-3456-4336-b653-022ba38d2084","type":"LinearScale"}},"id":"adce374e-6862-493e-9773-d5e0ac1cc735","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"455c7866-3456-4336-b653-022ba38d2084","type":"LinearScale"},{"attributes":{},"id":"8be97a7b-50b7-4e95-aaaa-2af4b70d976f","type":"BasicTickFormatter"},{"attributes":{"color_mapper":{"id":"c5a59ce6-c000-4956-b53a-6f82f1a227d4","type":"LinearColorMapper"},"dh":{"units":"data","value":339},"dw":{"units":"data","value":300},"image":{"field":"image"},"x":{"value":0},"y":{"value":0}},"id":"8b8baaf5-7b57-4f0a-a68d-c7ef5c24aff2","type":"Image"},{"attributes":{"formatter":{"id":"87f4e988-f640-4e3a-9592-0f8d009295ff","type":"BasicTickFormatter"},"plot":{"id":"adce374e-6862-493e-9773-d5e0ac1cc735","subtype":"Figure","type":"Plot"},"ticker":{"id":"9548f572-ebc5-4982-9544-bbe17844c8a7","type":"BasicTicker"}},"id":"76fc395e-dd43-4bb3-a236-0c9fc9a2294e","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"adce374e-6862-493e-9773-d5e0ac1cc735","subtype":"Figure","type":"Plot"},"ticker":{"id":"9548f572-ebc5-4982-9544-bbe17844c8a7","type":"BasicTicker"}},"id":"dfea6000-77d8-4bc8-bff0-c41c38b2b5ba","type":"Grid"},{"attributes":{"color_mapper":{"id":"abb29208-1472-4c1f-b12e-9188a853e3b8","type":"LinearColorMapper"},"dh":{"units":"data","value":339},"dw":{"units":"data","value":300},"image":{"field":"image"},"x":{"value":0},"y":{"value":0}},"id":"0d8d8b26-029a-4cc1-858d-1d67830d50fe","type":"Image"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9b2860b6-f356-4f6f-b3db-3f705acfe2a9","type":"PanTool"},{"id":"d456ce97-601c-429d-85f0-9f43e55c6f4e","type":"WheelZoomTool"},{"id":"70715e8c-3b28-49bc-9f3b-9d3f996d593d","type":"BoxZoomTool"},{"id":"20505d08-7db5-4d9b-84da-faf8b63fb0c6","type":"SaveTool"},{"id":"c6fd4c69-ea4d-4a87-9f0b-71f02e0cd0e1","type":"ResetTool"},{"id":"70ce219a-ac71-48be-b44f-cab4c916f5cb","type":"HelpTool"}]},"id":"15d172b5-79ea-40be-8982-eaf2f01629f2","type":"Toolbar"},{"attributes":{"callback":null,"end":339},"id":"bdae3ee3-e1bf-4fb7-bf0f-8ad347485f77","type":"Range1d"},{"attributes":{"plot":{"id":"adce374e-6862-493e-9773-d5e0ac1cc735","subtype":"Figure","type":"Plot"}},"id":"70ce219a-ac71-48be-b44f-cab4c916f5cb","type":"HelpTool"},{"attributes":{"plot":{"id":"adce374e-6862-493e-9773-d5e0ac1cc735","subtype":"Figure","type":"Plot"},"ticker":{"id":"5b67f3f4-cee9-4341-a857-73d6ed16ea70","type":"BasicTicker"}},"id":"0981332a-f48e-4cc2-a96a-57b5f9ac2c66","type":"Grid"},{"attributes":{"plot":null,"text":""},"id":"4dd23dee-564f-44db-8f29-73f29267aa29","type":"Title"},{"attributes":{},"id":"e9fc8f12-2a66-4d48-8dae-eccf804db5ad","type":"LinearScale"},{"attributes":{"formatter":{"id":"8be97a7b-50b7-4e95-aaaa-2af4b70d976f","type":"BasicTickFormatter"},"plot":{"id": ...

# %% [markdown]
# ### Hysteresis thresholding

# %%
hysteric = cp_double_threshold(sobel, thin_edges, 150., 200.)

# %%
fig_hyst = figure(x_range=(0, data.shape[1]), y_range=(0, data.shape[0]), plot_width=640, plot_height=700)
img = fig_hyst.image(image=[hysteric], x=0, y=0, dw=data.shape[1], dh=data.shape[0], palette=bokeh.palettes.grey(2)[::-1])
show(fig_hyst)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a5bcb561-43a7-4a26-900c-e5d9becad25d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a5bcb561-43a7-4a26-900c-e5d9becad25d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a5bcb561-43a7-4a26-900c-e5d9becad25d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a5bcb561-43a7-4a26-900c-e5d9becad25d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"dbea1ece-7eb5-40de-aad8-71e91465ce0b":{"roots":{"references":[{"attributes":{"palette":["#ffffff","#000000"]},"id":"2519b733-a90e-4ea5-89f9-98f2f3496395","type":"LinearColorMapper"},{"attributes":{"below":[{"id":"70ae1fa3-6f55-4d7e-8067-da5fad9b6479","type":"LinearAxis"}],"left":[{"id":"c73c03f4-ad00-4129-9b71-3d2efff06a2d","type":"LinearAxis"}],"plot_height":700,"plot_width":640,"renderers":[{"id":"70ae1fa3-6f55-4d7e-8067-da5fad9b6479","type":"LinearAxis"},{"id":"507bb55e-8ee7-410d-b7f3-61062533275f","type":"Grid"},{"id":"c73c03f4-ad00-4129-9b71-3d2efff06a2d","type":"LinearAxis"},{"id":"75a8f729-5517-4a11-8cfd-81a7f5977d38","type":"Grid"},{"id":"6368a4b6-86ab-427a-a9d3-c8a6e6497910","type":"BoxAnnotation"},{"id":"39899e60-5e48-4ab5-aac4-21880915b9f3","type":"GlyphRenderer"}],"title":{"id":"24a488a4-c3d4-467c-8124-cab204ce69a2","type":"Title"},"tool_events":{"id":"9ca8c1ff-095a-46ed-98d0-6be4f712b344","type":"ToolEvents"},"toolbar":{"id":"8292ca70-bb66-40cb-a7e5-b5a210a21996","type":"Toolbar"},"x_range":{"id":"0f5ff500-e5d6-4cfa-b9c8-962dc37f1c0e","type":"Range1d"},"x_scale":{"id":"e38abec1-9bf0-4f48-a34e-040a3a812d6d","type":"LinearScale"},"y_range":{"id":"ef4fd8f6-bf02-4f61-9d58-b75f5c93d263","type":"Range1d"},"y_scale":{"id":"513c4315-88f3-49f4-a30a-73789e219444","type":"LinearScale"}},"id":"bfec0a1c-c948-41ce-9bb1-700617eeb595","subtype":"Figure","type":"Plot"},{"attributes":{"color_mapper":{"id":"8913d6bc-a93c-4ca2-86ef-954a94ebbe0a","type":"LinearColorMapper"},"dh":{"units":"data","value":339},"dw":{"units":"data","value":300},"image":{"field":"image"},"x":{"value":0},"y":{"value":0}},"id":"5d84d84b-3467-4073-9fe2-edcaba0a0ddb","type":"Image"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"6368a4b6-86ab-427a-a9d3-c8a6e6497910","type":"BoxAnnotation"},{"attributes":{},"id":"9ca8c1ff-095a-46ed-98d0-6be4f712b344","type":"ToolEvents"},{"attributes":{"plot":null,"text":""},"id":"24a488a4-c3d4-467c-8124-cab204ce69a2","type":"Title"},{"attributes":{},"id":"513c4315-88f3-49f4-a30a-73789e219444","type":"LinearScale"},{"attributes":{},"id":"80e57987-6ffd-4bfb-bc2d-ca84e23de43d","type":"BasicTickFormatter"},{"attributes":{},"id":"e38abec1-9bf0-4f48-a34e-040a3a812d6d","type":"LinearScale"},{"attributes":{"callback":null,"column_names":["image"],"data":{"image":[{"__ndarray__":"...","dtype":"uint8","shape":[339,300]}]}},"id":"9ea101a5-8bf0-4085-a24d-62ce1f486519","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":339},"id":"ef4fd8f6-bf02-4f61-9d58-b75f5c93d263","type":"Range1d"},{"attributes":{"plot":{"id":"bfec0a1c-c948-41ce-9bb1-700617eeb595","subtype":"Figure","type":"Plot"}},"id":"3f35d995-ddaf-43f7-bef7-cb555168a472","type":"PanTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"3f35d995-ddaf-43f7-bef7-cb555168a472","type":"PanTool"},{"id":"d206e209-60e7-4f10-9b47-051f4a9605ba","type":"WheelZoomTool"},{"id":"ef6e3250-aed9-46bc-bbd8-13c938aa2963","type":"BoxZoomTool"},{"id":"6a7f3274-9685-4cd8-94c4-0ef6726daee5","type":"SaveTool"},{"id":"6ad3c7f0-4e65-4094-8a76-a1ea4c236027","type":"ResetTool"},{"id":"087d76ba-e8b2-4c3f-8cda-2b0a1732bbdf","type":"HelpTool"}]},"id":"8292ca70-bb66-40cb-a7e5-b5a210a21996","type":"Toolbar"},{"attributes":{"plot":{"id":"bfec0a1c-c948-41ce-9bb1-700617eeb595","subtype":"Figure","type":"Plot"},"ticker":{"id":"93d31098-53c9-4356-aa8a-b0aac8c99ee1","type":"BasicTicker"}},"id":"507bb55e-8ee7-410d-b7f3-61062533275f","type":"Grid"},{"attributes":{"overlay":{"id":"6368a4b6-86ab-427a-a9d3-c8a6e6497910","type":"BoxAnnotation"},"plot":{"id":"bfec0a1c-c948-41ce-9bb1-700617eeb595","subtype":"Figure","type":"Plot"}},"id":"ef6e32 ...

# %% [markdown]
# ## Putting it together

# %%
fig = figure(x_range=(0, data.shape[1]), y_range=(0, data.shape[0]), plot_width=500, plot_height=600)
img = fig.image(image=[data], x=0, y=0, dw=data.shape[1], dh=data.shape[0], palette=bokeh.palettes.grey(3)[::-1])

s = None
m = None
s_state = 0.0

def update(sigma, low, high):
    global s, m, s_state
    if abs(sigma - s_state) > 0.1:
        s_state = sigma
        # print("sobel", flush=True)
        s = smooth_sobel(data.copy(), int(np.floor(sigma*2)), sigma)
        # print("thinning edges", flush=True)
        m = edge_thinning(s)
    # print("double threshold", flush=True)
    c = cp_double_threshold(s, m, low, high)
    img.data_source.data['image'] = [c]
    push_notebook()

# %%
show(fig, notebook_handle=True)
interact(update, sigma=(0., 10.), low=(0., 200.), high=(0., 200.))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b55cae70-d9b0-456f-8e6d-92a9569ba789"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b55cae70-d9b0-456f-8e6d-92a9569ba789");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("91585e74-b16a-4a93-b4ff-ad494e762c0e", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b55cae70-d9b0-456f-8e6d-92a9569ba789");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b55cae70-d9b0-456f-8e6d-92a9569ba789' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1a6ea5e7-df49-489d-8ee8-cafeb1750fe9":{"roots":{"references":[{"attributes":{"callback":null,"end":339},"id":"0e7f63a6-8b42-46f1-b392-76ee3b73315c","type":"Range1d"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2d7bff90-afd8-4448-aef1-5c262cf6074e","type":"PanTool"},{"id":"c71284bf-a6a1-4df2-8ea0-abdb8a95d805","type":"WheelZoomTool"},{"id":"99fde269-c1ff-4573-8b91-00bb3971db4d","type":"BoxZoomTool"},{"id":"f1f06ff3-b335-41ab-9051-bdde99359341","type":"SaveTool"},{"id":"70061141-f136-4eaa-8119-9f2ec6f93f67","type":"ResetTool"},{"id":"5578de93-a316-487f-a11e-90e5b6029019","type":"HelpTool"}]},"id":"e8327dc7-29f2-42fc-a5e4-2d95d723d6b8","type":"Toolbar"},{"attributes":{},"id":"7b22d5b1-df7b-4b2c-979d-21332e85fdb9","type":"BasicTickFormatter"},{"attributes":{},"id":"b43ce7e4-3980-4e56-8a4f-84c5050d10b1","type":"LinearScale"},{"attributes":{"dimension":1,"plot":{"id":"c05508fa-6d96-4a23-a15f-780defdd2836","subtype":"Figure","type":"Plot"},"ticker":{"id":"2d61a9ec-8c16-4fc7-81cc-b3bf9eee8c9e","type":"BasicTicker"}},"id":"a6ef4592-ee9b-45a9-867b-bbf0e74b539c","type":"Grid"},{"attributes":{"plot":{"id":"c05508fa-6d96-4a23-a15f-780defdd2836","subtype":"Figure","type":"Plot"},"ticker":{"id":"01ed003a-3671-4906-aacf-72a47a553d3b","type":"BasicTicker"}},"id":"20d94780-8a83-451a-aef5-bb9c73dfee99","type":"Grid"},{"attributes":{"palette":["#ffffff","#7f7f7f","#000000"]},"id":"54e1457a-1890-4e87-ac5d-f4989e572a61","type":"LinearColorMapper"},{"attributes":{"formatter":{"id":"b3529f3b-685d-4088-a740-7ded1dd4dc05","type":"BasicTickFormatter"},"plot":{"id":"c05508fa-6d96-4a23-a15f-780defdd2836","subtype":"Figure","type":"Plot"},"ticker":{"id":"2d61a9ec-8c16-4fc7-81cc-b3bf9eee8c9e","type":"BasicTicker"}},"id":"df31ee8a-7c09-4985-a739-cc05c5909bce","type":"LinearAxis"},{"attributes":{"palette":["#ffffff","#7f7f7f","#000000"]},"id":"1892d748-2d0b-4340-9478-6bb673fc21c6","type":"LinearColorMapper"},{"attributes":{},"id":"b3529f3b-685d-4088-a740-7ded1dd4dc05","type":"BasicTickFormatter"},{"attributes":{"color_mapper":{"id":"1892d748-2d0b-4340-9478-6bb673fc21c6","type":"LinearColorMapper"},"dh":{"units":"data","value":339},"dw":{"units":"data","value":300},"image":{"field":"image"},"x":{"value":0},"y":{"value":0}},"id":"b43d16aa-5a0a-4112-961e-77478c56e0bc","type":"Image"},{"attributes":{"plot":{"id":"c05508fa-6d96-4a23-a15f-780defdd2836","subtype":"Figure","type":"Plot"}},"id":"2d7bff90-afd8-4448-aef1-5c262cf6074e","type":"PanTool"},{"attributes":{"plot":{"id":"c05508fa-6d96-4a23-a15f-780defdd2836","subtype":"Figure","type":"Plot"}},"id":"c71284bf-a6a1-4df2-8ea0-abdb8a95d805","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"54a4d0fa-d1e7-4c5c-894b-e52b0cde03d4","type":"LinearAxis"}],"left":[{"id":"df31ee8a-7c09-4985-a739-cc05c5909bce","type":"LinearAxis"}],"plot_width":500,"renderers":[{"id":"54a4d0fa-d1e7-4c5c-894b-e52b0cde03d4","type":"LinearAxis"},{"id":"20d94780-8a83-451a-aef5-bb9c73dfee99","type":"Grid"},{"id":"df31ee8a-7c09-4985-a739-cc05c5909bce","type":"LinearAxis"},{"id":"a6ef4592-ee9b-45a9-867b-bbf0e74b539c","type":"Grid"},{"id":"e08c6603-9df1-4af0-8de2-b4882c119e93","type":"BoxAnnotation"},{"id":"3879b6d3-d90d-416e-bc38-04e79bc52689","type":"GlyphRenderer"}],"title":{"id":"6072c8c4-dd6f-4cba-a3ec-a6512ccfd22b","type":"Title"},"tool_events":{"id":"c02bf620-c043-4ec7-aadf-4d7ff38621a2","type":"ToolEvents"},"toolbar":{"id":"e8327dc7-29f2-42fc-a5e4-2d95d723d6b8","type":"Toolbar"},"x_range":{"id":"6a5e21ef-9568-4e4b-a55f-85e974b88d14","type":"Range1d"},"x_scale":{"id":"b43ce7e4-3980-4e56-8a4f-84c5050d10b1","type":"LinearScale"},"y_range":{"id":"0e7f63a6-8b42-46f1-b392-76ee3b73315c","type":"Range1d"},"y_scale":{"id":"fde44908-fdc9-45d6-9b02-816a81995980","type":"LinearScale"}},"id":"c05508fa-6d96-4a23-a15f-780defdd2836","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"c05508fa-6d96-4a23-a15f-780defdd2836","subtype":"Figure ...
# <function __main__.update>
